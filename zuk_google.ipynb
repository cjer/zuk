# %% [markdown]
# 1. scraping libraries
# 1. google official
# 1. https://github.com/serpapi/google-search-results-python

# %%
from google import google
num_page = 3
search_results = google.search("צוק איתן", num_page)

# %%
dir(search_results[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_limit_str_size',
#  'cached',
#  'description',
#  'google_link',
#  'index',
#  'link',
#  'name',
#  'number_of_results',
#  'page',
#  'thumb']

# %%
search_results[0].description
# Out:
# 'מבצע צוק איתן נחשב למבצע הצבאי הנרחב ביותר של צה"ל מאז מלחמת לבנון השנייה, הן מבחינת משך הלחימה, מספר ההרוגים והפצועים בצד הישראלי ובצד הפלסטיני, עלותו הכספית לשני\xa0...'

# %%
search_results[0].index
# Out:
# 0

# %%
r = google.search("צוק איתן", num_page, lang='he', area='il', ncr=True, )

# %% [markdown]
# ## Official API
# https://stackoverflow.com/questions/37083058/programmatically-searching-google-in-python-using-custom-search

# %%
from googleapiclient.discovery import build
import pprint

my_api_key = 'AIzaSyDpVKwqm9WQxkoTy6IRTGxGMRksIOkJ_hw'
my_cse_id = '005044589920986654015:adeoqvvoihq'

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(
    'Operation Protective Edge', my_api_key, my_cse_id, num=10, gl='uk')
for result in results:
    pprint.pprint(result)
# Out:
# {'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/2014_Israel–Gaza_conflict',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/2014_Israel–Gaza_conflict',
#  'htmlSnippet': 'The 2014 Israel–Gaza conflict also known as <b>Operation '
#                 'Protective Edge</b> and <br>\n'
#                 'sometimes referred to as the 2014 Gaza war, was a military '
#                 'operation launched <br>\n'
#                 'by&nbsp;...',
#  'htmlTitle': '2014 Israel–Gaza conflict - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/2014_Israel%E2%80%93Gaza_conflict',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/b/b9/The_home_of_the_Kware%27_family%2C_after_it_was_bombed_by_the_military.jpg'}],
#              'cse_thumbnail': [{'height': '194',
# ...
