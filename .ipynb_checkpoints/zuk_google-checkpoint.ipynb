# %% [markdown]
# 1. scraping libraries
# 1. google official
# 1. https://github.com/serpapi/google-search-results-python

# %%
from google import google
num_page = 3
search_results = google.search("צוק איתן", num_page)

# %%
dir(search_results[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_limit_str_size',
#  'cached',
#  'description',
#  'google_link',
#  'index',
#  'link',
#  'name',
#  'number_of_results',
#  'page',
#  'thumb']

# %%
search_results[0].description
# Out:
# 'מבצע צוק איתן נחשב למבצע הצבאי הנרחב ביותר של צה"ל מאז מלחמת לבנון השנייה, הן מבחינת משך הלחימה, מספר ההרוגים והפצועים בצד הישראלי ובצד הפלסטיני, עלותו הכספית לשני\xa0...'

# %%
search_results[0].index
# Out:
# 0

# %%
r = google.search("צוק איתן", num_page, lang='he', area='il', ncr=True, )

# %% [markdown]
# ## Official API
# https://stackoverflow.com/questions/37083058/programmatically-searching-google-in-python-using-custom-search

# %%
from googleapiclient.discovery import build
import pprint

my_api_key = 'AIzaSyDpVKwqm9WQxkoTy6IRTGxGMRksIOkJ_hw'
my_cse_id = '005044589920986654015:adeoqvvoihq'

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(
    'מבצע צוק איתן', my_api_key, my_cse_id, num=10)
for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': 'ugnGbYnafTMJ',
#  'displayLink': 'he.wikipedia.org',
#  'formattedUrl': 'https://he.wikipedia.org/wiki/מבצע_צוק_איתן',
#  'htmlFormattedUrl': 'https://he.wikipedia.org/wiki/<b>מבצע</b>_<b>צוק</b>_<b>איתן</b>',
#  'htmlSnippet': '<b>מבצע צוק איתן</b> נחשב למבצע הצבאי הנרחב ביותר של '
#                 'צה&quot;ל מאז מלחמת לבנון השנייה, הן <br>\n'
#                 'מבחינת משך הלחימה, מספר ההרוגים והפצועים בצד הישראלי ובצד '
#                 'הפלסטיני, עלותו הכספית <br>\n'
#                 'לשני&nbsp;...',
#  'htmlTitle': '<b>מבצע צוק איתן</b> – ויקיפדיה',
#  'kind': 'customsearch#result',
#  'link': 'https://he.wikipedia.org/wiki/%D7%9E%D7%91%D7%A6%D7%A2_%D7%A6%D7%95%D7%A7_%D7%90%D7%99%D7%AA%D7%9F',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Iron_Dome_in_Operation_Protective_Edge.jpg/1200px-Iron_Dome_in_Operation_Protective_Edge.jpg'}],
#              'cse_thumbnail': [{'height': '183',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcR3oBP8toMRtVKnQLvBW1hODOdb4amlhtny88MiOm4NsybCb1vq-jjj4lLc',
#                                 'width': '275'}],
#              'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Iron_Dome_in_Operation_Protective_Edge.jpg/1200px-Iron_Dome_in_Operation_Protective_Edge.jpg',
#                            'referrer': 'origin'}]},
#  'snippet': 'מבצע צוק איתן נחשב למבצע הצבאי הנרחב ביותר של צה"ל מאז מלחמת '
#             'לבנון השנייה, הן \n'
#             'מבחינת משך הלחימה, מספר ההרוגים והפצועים בצד הישראלי ובצד '
#             'הפלסטיני, עלותו הכספית \n'
#             'לשני\xa0...',
#  'title': 'מבצע צוק איתן – ויקיפדיה'}
# {'cacheId': 'YY_wzPy3464J',
#  'displayLink': 'www.youtube.com',
#  'formattedUrl': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM',
#  'htmlFormattedUrl': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM',
#  'htmlSnippet': '20 יולי 2014 <b>...</b> נמשך המאמץ היבשתי במסגרת <b>מבצע</b> '
#                 '&quot;<b>צוק איתן</b>&quot;, אליו יצא צה&quot;ל על רקע ירי '
#                 'הרקטות הנרחב <br>\n'
#                 'ליישובי הדרום. בשלב זה, הפעולה היבשתית הינה ממוקדת ומטרתה '
#                 'סיכול&nbsp;...',
#  'htmlTitle': '<b>מבצע</b> &quot;<b>צוק איתן</b>&quot;: חילופי אש בין גולני '
#               'למחבלים     - YouTube',
#  'kind': 'customsearch#result',
#  'link': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM',
#  'pagemap': {'cse_image': [{'src': 'https://i.ytimg.com/vi/BPzqZ5rSDkM/maxresdefault.jpg'}],
#              'cse_thumbnail': [{'height': '168',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSvoje6EXMfOXdS3EZ00hC3FyjJ0-uDSEZYy2oObsMQxcCE-lpA_cC41Zik',
#                                 'width': '300'}],
#              'imageobject': [{'height': '720',
#                               'url': 'https://i.ytimg.com/vi/BPzqZ5rSDkM/maxresdefault.jpg',
#                               'width': '1280'}],
#              'metatags': [{'al:android:app_name': 'YouTube',
#                            'al:android:package': 'com.google.android.youtube',
#                            'al:android:url': 'vnd.youtube://www.youtube.com/watch?v=BPzqZ5rSDkM&feature=applinks',
#                            'al:ios:app_name': 'YouTube',
#                            'al:ios:app_store_id': '544007664',
#                            'al:ios:url': 'vnd.youtube://www.youtube.com/watch?v=BPzqZ5rSDkM&feature=applinks',
#                            'al:web:url': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM&feature=applinks',
#                            'fb:app_id': '87741124305',
#                            'og:description': 'נמשך המאמץ היבשתי במסגרת מבצע '
#                                              '"צוק איתן", אליו יצא צה"ל על רקע '
#                                              'ירי הרקטות הנרחב ליישובי הדרום. '
#                                              'בשלב זה, הפעולה היבשתית הינה '
#                                              'ממוקדת ומטרתה סיכול תשתיות הטרור '
#                                              '...',
#                            'og:image': 'https://i.ytimg.com/vi/BPzqZ5rSDkM/maxresdefault.jpg',
#                            'og:site_name': 'YouTube',
#                            'og:title': 'מבצע "צוק איתן": חילופי אש בין גולני '
#                                        'למחבלים',
#                            'og:type': 'video.other',
#                            'og:url': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM',
#                            'og:video:height': '720',
#                            'og:video:secure_url': 'https://www.youtube.com/embed/BPzqZ5rSDkM',
#                            'og:video:tag': 'צהל',
#                            'og:video:type': 'text/html',
#                            'og:video:url': 'https://www.youtube.com/embed/BPzqZ5rSDkM',
#                            'og:video:width': '1280',
#                            'theme-color': '#ff0000',
#                            'title': 'מבצע "צוק איתן": חילופי אש בין גולני '
#                                     'למחבלים',
#                            'twitter:app:id:ipad': '544007664',
#                            'twitter:app:id:iphone': '544007664',
#                            'twitter:app:name:ipad': 'YouTube',
#                            'twitter:app:name:iphone': 'YouTube',
#                            'twitter:app:url:iphone': 'vnd.youtube://www.youtube.com/watch?v=BPzqZ5rSDkM&feature=applinks',
#                            'twitter:card': 'player',
#                            'twitter:description': 'נמשך המאמץ היבשתי במסגרת '
#                                                   'מבצע "צוק איתן", אליו יצא '
#                                                   'צה"ל על רקע ירי הרקטות '
#                                                   'הנרחב ליישובי הדרום. בשלב '
#                                                   'זה, הפעולה היבשתית הינה '
#                                                   'ממוקדת ומטרתה סיכול תשתיות '
#                                                   'הטרור ...',
#                            'twitter:image': 'https://i.ytimg.com/vi/BPzqZ5rSDkM/maxresdefault.jpg',
#                            'twitter:site': '@youtube',
#                            'twitter:title': 'מבצע "צוק איתן": חילופי אש בין '
#                                             'גולני למחבלים',
#                            'twitter:url': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM'}],
#              'person': [{'url': 'http://www.youtube.com/user/idfspox1'},
#                         {'url': 'https://plus.google.com/108971959124435219022'}],
#              'videoobject': [{'channelid': 'UCjBj9fgK60mlAH-nvtSOojg',
#                               'datepublished': '2014-07-20',
#                               'description': 'נמשך המאמץ היבשתי במסגרת מבצע '
#                                              '"צוק איתן", אליו יצא צה"ל על רקע '
#                                              'ירי הרקטות הנרחב ליישובי הדרום. '
#                                              'בשלב זה, הפעולה...',
#                               'duration': 'PT1M2S',
#                               'embedurl': 'https://www.youtube.com/embed/BPzqZ5rSDkM',
#                               'genre': 'News & Politics',
#                               'height': '720',
#                               'interactioncount': '112459',
#                               'isfamilyfriendly': 'True',
#                               'name': 'מבצע "צוק איתן": חילופי אש בין גולני '
#                                       'למחבלים',
#                               'paid': 'False',
#                               'playertype': 'HTML5 Flash',
#                               'regionsallowed': 'AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH...',
#                               'thumbnailurl': 'https://i.ytimg.com/vi/BPzqZ5rSDkM/maxresdefault.jpg',
#                               'unlisted': 'False',
#                               'url': 'https://www.youtube.com/watch?v=BPzqZ5rSDkM',
#                               'videoid': 'BPzqZ5rSDkM',
#                               'width': '1280'}]},
#  'snippet': '20 יולי 2014 ... נמשך המאמץ היבשתי במסגרת מבצע "צוק איתן", אליו '
#             'יצא צה"ל על רקע ירי הרקטות הנרחב \n'
#             'ליישובי הדרום. בשלב זה, הפעולה היבשתית הינה ממוקדת ומטרתה '
#             'סיכול\xa0...',
#  'title': 'מבצע "צוק איתן": חילופי אש בין גולני למחבלים     - YouTube'}
# {'cacheId': 'rd8wL-EeCkYJ',
#  'displayLink': 'he.wikipedia.org',
#  'formattedUrl': 'https://he.wikipedia.org/wiki/אירועי_מבצע_צוק_איתן',
#  'htmlFormattedUrl': 'https://he.wikipedia.org/wiki/אירועי_<b>מבצע</b>_<b>צוק</b>_<b>איתן</b>',
#  'htmlSnippet': '<b>מבצע צוק איתן</b> הוא <b>מבצע</b> צבאי נרחב של צה&quot;ל '
#                 'ברצועת עזה שהתחיל ב-8 ביולי 2014, ונמשך <br>\n'
#                 'עד להפסקת אש ב-26 באוגוסט. המבצע החל בעקבות ירי רקטות מרצועת '
#                 'עזה לעבר אוכלוסייה<br>\n'
#                 '&nbsp;...',
#  'htmlTitle': 'אירועי <b>מבצע צוק איתן</b> – ויקיפדיה',
#  'kind': 'customsearch#result',
#  'link': 'https://he.wikipedia.org/wiki/%D7%90%D7%99%D7%A8%D7%95%D7%A2%D7%99_%D7%9E%D7%91%D7%A6%D7%A2_%D7%A6%D7%95%D7%A7_%D7%90%D7%99%D7%AA%D7%9F',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Iron_Dome_in_Operation_Protective_Edge.jpg/1200px-Iron_Dome_in_Operation_Protective_Edge.jpg'}],
#              'cse_thumbnail': [{'height': '183',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcR3oBP8toMRtVKnQLvBW1hODOdb4amlhtny88MiOm4NsybCb1vq-jjj4lLc',
#                                 'width': '275'}],
#              'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Iron_Dome_in_Operation_Protective_Edge.jpg/1200px-Iron_Dome_in_Operation_Protective_Edge.jpg',
#                            'referrer': 'origin'}]},
#  'snippet': 'מבצע צוק איתן הוא מבצע צבאי נרחב של צה"ל ברצועת עזה שהתחיל ב-8 '
#             'ביולי 2014, ונמשך \n'
#             'עד להפסקת אש ב-26 באוגוסט. המבצע החל בעקבות ירי רקטות מרצועת עזה '
#             'לעבר אוכלוסייה\n'
#             '\xa0...',
#  'title': 'אירועי מבצע צוק איתן – ויקיפדיה'}
# {'cacheId': '5GhHdgVy3zIJ',
#  'displayLink': 'www.ynet.co.il',
#  'formattedUrl': 'https://www.ynet.co.il/articles/0,7340,L-4555306,00.html',
#  'htmlFormattedUrl': 'https://www.ynet.co.il/articles/0,7340,L-4555306,00.html',
#  'htmlSnippet': '5 אוגוסט 2014 <b>...</b> בהודעת האוניברסיטה נמסר כי באותו יום '
#                 'יחלו הבחינות שבוטלו על פי התכנון המקורי בעקבות <br>\n'
#                 '<b>מבצע</b> &quot;<b>צוק איתן</b>&quot;. כמו כן, הוחלט לקיים '
#                 'מחזור בחינות נוסף בתאריכים&nbsp;...',
#  'htmlTitle': '3,356 רקטות, 4,762 תקיפות, 82,201 מילואימניקים. <b>צוק איתן</b> '
#               'במספרים',
#  'kind': 'customsearch#result',
#  'link': 'https://www.ynet.co.il/articles/0,7340,L-4555306,00.html',
#  'pagemap': {'cse_image': [{'height': '103',
#                             'src': 'https://images1.ynet.co.il/PicServer4/2014/08/05/5504882/untitled1.jpg_sm.jpg',
#                             'type': '1',
#                             'width': '183'}],
#              'metatags': [{'application-name': 'ynet',
#                            'fb:app_id': '117633148253098',
#                            'og:description': 'במהלך המבצע הארוך ביותר של צה"ל '
#                                              'בעזה יירטה כיפת ברזל 578 רקטות, '
#                                              '116 אחרות נפלו בשטח בנוי. 64 '
#                                              'חיילים שילמו בחייהם, בעזה נהרגו '
#                                              '1,768 פלסטינים. 485 אלף עזתים '
#                                              'הפכו לפליטים. כל המספרים',
#                            'og:image': 'https://www.ynet.co.il/PicServer4/2014/08/05/5506516/gaza_killed1.jpg',
#                            'og:ispay': '0',
#                            'og:published_time': '17:42 , 05.08.14',
#                            'og:site_name': 'ynet',
#                            'og:title': '3,356 רקטות, 4,762 תקיפות, 82,201 '
#                                        'מילואימניקים. צוק איתן במספרים',
#                            'og:type': 'article',
#                            'og:url': 'https://www.ynet.co.il/articles/0,7340,L-4555306,00.html',
#                            'thumbnail': 'http://www.ynet.co.il/PicServer4/2014/08/05/5504886/550488517512385116116no.jpg',
#                            'vr:author': 'יואב זיתון',
#                            'vr:category': 'News',
#                            'vr:image': 'https://images1.ynet.co.il/PicServer4/2014/08/05/5505499/2_ra.jpg',
#                            'vr:published_time': '17:42 , 05.08.14',
#                            'vr:title': '3,356 רקטות, 4,762 תקיפות, 82,201 '
#                                        'מילואימניקים. צוק איתן במספרים',
#                            'vr:type': 'video'}],
#              'thumbnail': [{'src': 'http://www.ynet.co.il/PicServer4/2014/08/05/5504886/550488517512385116116no.jpg'}]},
#  'snippet': '5 אוגוסט 2014 ... בהודעת האוניברסיטה נמסר כי באותו יום יחלו '
#             'הבחינות שבוטלו על פי התכנון המקורי בעקבות \n'
#             'מבצע "צוק איתן". כמו כן, הוחלט לקיים מחזור בחינות נוסף '
#             'בתאריכים\xa0...',
#  'title': '3,356 רקטות, 4,762 תקיפות, 82,201 מילואימניקים. צוק איתן במספרים'}
# {'cacheId': 'RZk6SLWKyrYJ',
#  'displayLink': 'www.mevaker.gov.il',
#  'formattedUrl': 'www.mevaker.gov.il/he/Reports/Pages/568.aspx?...1',
#  'htmlFormattedUrl': 'www.mevaker.gov.il/he/Reports/Pages/568.aspx?...1',
#  'htmlSnippet': '28 פברואר 2017 <b>...</b> פתח דבר. <b>מבצע</b> &quot;<b>צוק '
#                 'איתן</b>&quot; ברצועת עזה החל ב-7 ביולי 2014 ונמשך כ-50 ימים, '
#                 'שבמהלכם <br>\n'
#                 'לחמו חיילי צה&quot;ל ומפקדיו באומץ ובעוז נפש, בעיקר מול החמאס '
#                 'והג&#39;יאהד&nbsp;...',
#  'htmlTitle': '<b>מבצע</b> &quot;<b>צוק איתן</b>&quot;',
#  'kind': 'customsearch#result',
#  'link': 'http://www.mevaker.gov.il/he/Reports/Pages/568.aspx?AspxAutoDetectCookieSupport=1',
#  'pagemap': {'cse_image': [{'src': '/_layouts/15/Images/Guardian.Resources/news-img2.jpg'}],
#              'metatags': [{'msapplication-tilecolor': '#0072C6',
#                            'msapplication-tileimage': '/_layouts/15/images/SharePointMetroAppTile.png',
#                            'og:description': 'מבצע',
#                            'og:image': '/_layouts/15/Images/Guardian.Resources/news-img2.jpg',
#                            'og:title': 'מבצע',
#                            'og:url': 'http://www.mevaker.gov.il/he/Reports/Pages/568.aspx?AspxAutoDetectCookieSupport=1'}]},
#  'snippet': '28 פברואר 2017 ... פתח דבר. מבצע "צוק איתן" ברצועת עזה החל ב-7 '
#             'ביולי 2014 ונמשך כ-50 ימים, שבמהלכם \n'
#             'לחמו חיילי צה"ל ומפקדיו באומץ ובעוז נפש, בעיקר מול החמאס '
#             "והג'יאהד\xa0...",
#  'title': 'מבצע "צוק איתן"'}
# {'cacheId': 't760CDRvqfIJ',
#  'displayLink': 'taxes.gov.il',
#  'fileFormat': 'PDF/Adobe Acrobat',
#  'formattedUrl': 'https://taxes.gov.il/.../הוראת%20ביצוע%20צוק%20איתן%2010.8.14%20לאינטרנט. '
#                  'pdf',
#  'htmlFormattedUrl': 'https://taxes.gov.il/.../הוראת%20ביצוע%20<b>צוק</b>%20<b>איתן</b>%2010.8.14%20לאינטרנט. '
#                      'pdf',
#  'htmlSnippet': 'להוראת ביצוע זו(. על עוסק כאמור להצהיר ולהתחייב כי נגרם לו '
#                 'נזק עקיף בגין <b>מבצע</b> &quot;<b>צוק</b>. <b>איתן</b>&quot; '
#                 '<br>\n'
#                 'וכי בכוונתו להגיש תביעה לקבלת פיצוי בגין נזק זה. (3. מקדמה '
#                 'כאמור ניתן להגיש עד תאריך.',
#  'htmlTitle': 'הוראת ביצוע מיסוי מקרקעין מס&#39; 8/2014 -קרן פיצויים - פיצויים '
#               'בשל נזק עקיף ...',
#  'kind': 'customsearch#result',
#  'link': 'https://taxes.gov.il/about/publicannouncements/documents/100814/%D7%94%D7%95%D7%A8%D7%90%D7%AA%20%D7%91%D7%99%D7%A6%D7%95%D7%A2%20%D7%A6%D7%95%D7%A7%20%D7%90%D7%99%D7%AA%D7%9F%2010.8.14%20%D7%9C%D7%90%D7%99%D7%A0%D7%98%D7%A8%D7%A0%D7%98.pdf',
#  'mime': 'application/pdf',
#  'pagemap': {'cse_image': [{'src': 'x-raw-image:///b3f1b355871f48f3b341c5f9a9b71daa3463c9faaf76fa5a6e6221c525848395'}],
#              'cse_thumbnail': [{'height': '114',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTi-o8aJrRm3L88p6oYNiylNEBut0ybr-6fuKoXEphc8DQuO5t3__0Lsg',
#                                 'width': '113'}],
#              'metatags': [{'author': 'צוות דורמן',
#                            'creationdate': "D:20140904123952+03'00'",
#                            'creator': 'Microsoft® Word 2010',
#                            'moddate': "D:20140904123952+03'00'",
#                            'producer': 'Microsoft® Word 2010',
#                            'title': 'מודעה לציבור:'}]},
#  'snippet': 'להוראת ביצוע זו(. על עוסק כאמור להצהיר ולהתחייב כי נגרם לו נזק '
#             'עקיף בגין מבצע "צוק. איתן" \n'
#             'וכי בכוונתו להגיש תביעה לקבלת פיצוי בגין נזק זה. (3. מקדמה כאמור '
#             'ניתן להגיש עד תאריך.',
#  'title': "הוראת ביצוע מיסוי מקרקעין מס' 8/2014 -קרן פיצויים - פיצויים בשל נזק "
#           'עקיף ...'}
# {'cacheId': 'YJKXaMG5swIJ',
#  'displayLink': 'shironet.mako.co.il',
#  'formattedUrl': 'https://shironet.mako.co.il/html/indexes/works/223.html',
#  'htmlFormattedUrl': 'https://shironet.mako.co.il/html/indexes/works/223.html',
#  'htmlSnippet': 'Holy Land - דיאנה גולבי &middot; אורון - אריק סיני &middot; '
#                 'אחי הטוב שלי - חיים איפרגן &middot; אחי היקר - דור <br>\n'
#                 'שמעון &middot; אחרי שתחזרו - להקת הרבנות הצבאית &middot; '
#                 'אצלנו בגן - שי-לי עטרי &middot; אשיר לך - אנתוני צ&#39;<br>\n'
#                 'פמן&nbsp;...',
#  'htmlTitle': 'שירים בנושא: <b>מבצע</b> &quot;<b>צוק איתן</b>&quot; - שירונט',
#  'kind': 'customsearch#result',
#  'link': 'https://shironet.mako.co.il/html/indexes/works/223.html',
#  'pagemap': {'metatags': [{'distribution': 'Global',
#                            'expires': 'never',
#                            'language': 'hebrew'}]},
#  'snippet': 'Holy Land - דיאנה גולבי · אורון - אריק סיני · אחי הטוב שלי - חיים '
#             'איפרגן · אחי היקר - דור \n'
#             'שמעון · אחרי שתחזרו - להקת הרבנות הצבאית · אצלנו בגן - שי-לי עטרי '
#             "· אשיר לך - אנתוני צ'\n"
#             'פמן\xa0...',
#  'title': 'שירים בנושא: מבצע "צוק איתן" - שירונט'}
# {'cacheId': 'aYDdxZZ_ALIJ',
#  'displayLink': 'cms.education.gov.il',
#  'formattedUrl': 'cms.education.gov.il/EducationCMS/Units/Shefi/.../zokeitan.htm',
#  'htmlFormattedUrl': 'cms.education.gov.il/EducationCMS/Units/Shefi/.../zokeitan.htm',
#  'htmlSnippet': 'חופשת הקיץ התחילה עם תקווה לימים של פעילות משמחת, מרגיעה '
#                 'ומחזקת. השנה יצאנו <br>\n'
#                 'לחופשה לאחר רצף של אירועים קשים ולצערנו, בד בבד התרחב מאוד '
#                 'מעגל היישובים, הסובלים<br>\n'
#                 '&nbsp;...',
#  'htmlTitle': 'בעקבות <b>מבצע צוק איתן</b>',
#  'kind': 'customsearch#result',
#  'link': 'http://cms.education.gov.il/EducationCMS/Units/Shefi/HerumLachatzMashber/herum/zokeitan.htm',
#  'pagemap': {'metatags': [{'code_language': 'Visual Basic 7.0',
#                            'createdby': 'WinNT://NET/tp268',
#                            'createddate': '2014/7/10',
#                            'displayname': 'בעקבות מבצע צוק איתן',
#                            'displaypath': '/Channels/משרד החינוך/אתרי '
#                                           'יחידות/שרות פסיכולוגי ייעוצי/לחץ, '
#                                           'חירום ומשבר/חירום/בעקבות מבצע צוק '
#                                           'איתן',
#                            'expirydate': '3000/1/1',
#                            'guid': '{3E89A234-F303-4DAE-9C07-ECA9C8804EF8}',
#                            'isimportant': 'False',
#                            'lastapproveddeclinedby': 'WinNT://NET/tp268',
#                            'lastmodifiedby': 'WinNT://NET/tp268',
#                            'lastmodifieddate': '2016/8/27',
#                            'name': 'zokeitan',
#                            'path': '/Channels/EducationCMS/Units/Shefi/HerumLachatzMashber/herum/zokeitan',
#                            'rsspublishdate': '2014/07/10',
#                            'startdate': '2014/7/10',
#                            'url': '/EducationCMS/Units/Shefi/HerumLachatzMashber/herum/zokeitan.htm',
#                            'vs_defaultclientscript': 'JavaScript',
#                            'vs_targetschema': 'http://schemas.microsoft.com/intellisense/ie5',
#                            'העתקה לפורטל': 'True',
#                            'חדש באתר': 'true',
#                            'יחידה': 'שפ'}]},
#  'snippet': 'חופשת הקיץ התחילה עם תקווה לימים של פעילות משמחת, מרגיעה ומחזקת. '
#             'השנה יצאנו \n'
#             'לחופשה לאחר רצף של אירועים קשים ולצערנו, בד בבד התרחב מאוד מעגל '
#             'היישובים, הסובלים\n'
#             '\xa0...',
#  'title': 'בעקבות מבצע צוק איתן'}
# {'cacheId': 'apvkIRrI47UJ',
#  'displayLink': 'taxes.gov.il',
#  'formattedUrl': 'https://taxes.gov.il/EmergencyInformationA.../ZukEitan2014.aspx',
#  'htmlFormattedUrl': 'https://taxes.gov.il/EmergencyInformationA.../ZukEitan2014.aspx',
#  'htmlSnippet': 'הוראת ביצוע מיסוי מקרקעין מס&#39; 8/2014 -קרן פיצויים - '
#                 'פיצויים בשל נזק עקיף לניזוק שעסקו <br>\n'
#                 'באזור המיוחד לתקופה שמיום 8.7.2014 עד תום תקופת ההכרזה '
#                 '(<b>מבצע</b> &quot;<b>צוק איתן</b>&quot;) בענפי&nbsp;...',
#  'htmlTitle': '&quot;<b>צוק איתן</b>&quot; 2014',
#  'kind': 'customsearch#result',
#  'link': 'https://taxes.gov.il/EmergencyInformationA_CompensationfundPropertyTax/Pages/ZukEitan2014.aspx',
#  'pagemap': {'cse_image': [{'src': 'https://taxes.gov.il/PublishingImages/logoTaxes_jpg.jpg'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTTsJ5AfU8uDw5IkKMA9FEQxm-xEFxObkwdIDYVD7XufEgNN-55O2-VL7n_',
#                                 'width': '225'}],
#              'metatags': [{'comments': 'לחימה בדרום 2014',
#                            'created': '08/07/2014 17:09:13',
#                            'mmdaudience': 'אזרחים שרכושם נפגע בפעולות איבה '
#                                           'ולחימה,עסקים שנפגעו בפעולת איבה '
#                                           'ולחימה',
#                            'modified': '23/11/2017 11:35:49',
#                            'og:image': 'https://taxes.gov.il/PublishingImages/logoTaxes_jpg.jpg',
#                            'taxessearchdescription': 'מסמכי עזר לציבור '
#                                                      'שרכושו/עסקו נפגע באירועי '
#                                                      '2014 בדרום'}]},
#  'snippet': "הוראת ביצוע מיסוי מקרקעין מס' 8/2014 -קרן פיצויים - פיצויים בשל "
#             'נזק עקיף לניזוק שעסקו \n'
#             'באזור המיוחד לתקופה שמיום 8.7.2014 עד תום תקופת ההכרזה (מבצע "צוק '
#             'איתן") בענפי\xa0...',
#  'title': '"צוק איתן" 2014'}
# {'cacheId': 'b8yJPqFb2T0J',
#  'displayLink': 'news.walla.co.il',
#  'formattedUrl': 'https://news.walla.co.il/item/2762480',
#  'htmlFormattedUrl': 'https://news.walla.co.il/item/2762480',
#  'htmlSnippet': '<b>מבצע</b> &quot;<b>צוק איתן</b>&quot; של צה&quot;ל יצא לדרך '
#                 'בלילה שבין ה-7 ל-8 ביולי בהתקפה אווירית רחבה על <br>\n'
#                 'עשרות יעדים ברצועת עזה. המבצע נפתח בתום תקופה מתוחה שהחלה עם '
#                 'חטיפת הנערים גיל-<br>\n'
#                 'עד&nbsp;...',
#  'htmlTitle': 'סיקור מיוחד | מלחמה בדרום - <b>מבצע</b> &quot;<b>צוק '
#               'איתן</b>&quot; - וואלה! חדשות',
#  'kind': 'customsearch#result',
#  'link': 'https://news.walla.co.il/item/2762480',
#  'pagemap': {'Breadcrumb': [{'title': 'צבא וביטחון', 'url': 'צבא וביטחון'}],
#              'cse_image': [{'src': 'https://img.wcdn.co.il/f_auto,w_1200,t_54/ar_1.91,c_fill,g_auto/l_black_line,g_south,w_1.0,h_0.1,fl_relative,o_90/g_south_east,x_15,y_12,l_logo2,w_250/1/7/5/1/1751125-46.jpg'}],
#              'cse_thumbnail': [{'height': '162',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcR-myV1forSjVpiju34TAEGfhhZYoamJMvaDhndWBeo1A09ZNIXn-dXZ-RW',
#                                 'width': '311'}],
#              'metatags': [{'106420999416737': 'fb:pages',
#                            '114899355220533': 'fb:pages',
#                            '119476251424332': 'fb:pages',
#                            '123808954307758': 'fb:pages',
#                            '135130956523111': 'fb:pages',
#                            '135819839776959': 'fb:pages',
#                            '140399045970149': 'fb:pages',
#                            '160685207275958': 'fb:pages',
#                            '1713909145576885': 'fb:pages',
#                            '224716972030': 'fb:pages',
#                            '260459850653705': 'fb:pages',
#                            'al:ios:app_name': 'וואלה!NEWS - החדשות של ישראל',
#                            'al:ios:app_store_id': '336751384',
#                            'article:tag': 'מבצע צוק איתן,הסלמה בדרום,רצועת '
#                                           'עזה,מלחמה בעזה',
#                            'dc.date.issued': '2017-07-20',
#                            'fb:app_id': '133472246670311',
#                            'fb:pages': '135130956523111',
#                            'news_keywords': 'מבצע צוק איתן,הסלמה בדרום,רצועת '
#                                             'עזה,מלחמה בעזה',
#                            'og:description': 'מבצע "צוק איתן" של צה"ל יצא לדרך '
#                                              'בלילה שבין ה-7 ל-8 ביולי בהתקפה '
#                                              'אווירית רחבה על עשרות יעדים',
#                            'og:image': 'https://img.wcdn.co.il/f_auto,w_1200,t_54/ar_1.91,c_fill,g_auto/l_black_line,g_south,w_1.0,h_0.1,fl_relative,o_90/g_south_east,x_15,y_12,l_logo2,w_250/1/7/5/1/1751125-46.jpg',
#                            'og:site_name': 'וואלה! חדשות',
#                            'og:title': 'מלחמה בדרום - וואלה! חדשות',
#                            'og:type': 'article',
#                            'og:url': 'https://news.walla.co.il/item/2762480',
#                            'taboola:image': 'https://img.wcdn.co.il/f_auto,w_1200/1/7/5/1/1751125-46.jpg',
#                            'theme-color': '#1978bb',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:description': 'מבצע "צוק איתן" של צה"ל יצא '
#                                                   'לדרך בלילה שבין ה-7 ל-8 '
#                                                   'ביולי בהתקפה אווירית רחבה '
#                                                   'על עשרות יעדים',
#                            'twitter:image': 'https://img.wcdn.co.il/f_auto,w_1200,t_54/ar_1.91,c_fill,g_auto/l_black_line,g_south,w_1.0,h_0.1,fl_relative,o_90/g_south_east,x_15,y_12,l_logo2,w_250/1/7/5/1/1751125-46.jpg',
#                            'twitter:site': '@wallanews',
#                            'twitter:title': 'סיקור מיוחד | מלחמה בדרום - מבצע '
#                                             '"צוק איתן" - וואלה! חדשות',
#                            'viewport': 'width=device-width, initial-scale=1, '
#                                        'maximum-scale=2'}]},
#  'snippet': 'מבצע "צוק איתן" של צה"ל יצא לדרך בלילה שבין ה-7 ל-8 ביולי בהתקפה '
#             'אווירית רחבה על \n'
#             'עשרות יעדים ברצועת עזה. המבצע נפתח בתום תקופה מתוחה שהחלה עם '
#             'חטיפת הנערים גיל-\n'
#             'עד\xa0...',
#  'title': 'סיקור מיוחד | מלחמה בדרום - מבצע "צוק איתן" - וואלה! חדשות'}
